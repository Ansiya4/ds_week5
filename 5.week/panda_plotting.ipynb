# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/student_scores.csv')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.plot(kind='scatter',x= 'Hours',y='Scores')

# %%
df['Scores'].plot(kind='bar')

#Set labels and title
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.title('Scores vs. Hours')

#Show the plot
plt.show()

# %%
df.plot(kind='bar', x='Hours', y='Scores')
# Out:
# <Axes: xlabel='Hours'>

# %%
df.plot(kind='hist',y='Scores')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x='Scores', y='Hours', marker='o', linestyle='-', color='r')
# Out:
# <Axes: xlabel='Scores'>

# %%
data = {'x': [1,2,1,2],
        'y': [10,20,20,10]}

df = pd.DataFrame(data)
df.plot(x='x', y='y', marker='o', linestyle='-', color='b')
# Out:
# <Axes: xlabel='x'>
