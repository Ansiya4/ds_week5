# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.random.randint(10,100,10)

# %%
arr
# Out:
# array([68, 27, 81, 85, 60, 99, 97, 90, 59, 71])

# %%
n=len(arr)
# Out:
# 10

# %%
plt.scatter(np.arange(len(arr)),arr)
plt.xlabel=

# %%
plt.bar
