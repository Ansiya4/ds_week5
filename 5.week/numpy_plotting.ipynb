# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.randint(0,100,200)

# %%
data
# Out:
# array([37, 80, 56, 29, 77, 46, 23, 65, 58, 81, 32, 49, 12, 57, 85,  7, 40,
#        33, 35, 95, 49, 12, 84, 85, 43, 43, 52, 89, 64, 56, 75, 69, 50, 11,
#        68, 14, 64, 67, 20, 67,  1, 41, 82,  7, 94, 13, 59, 74, 28, 36, 53,
#        84, 50,  4, 91, 29, 50, 23, 69, 37, 78, 91, 82, 12,  6, 22, 90, 18,
#        37, 70,  0, 81, 29, 30, 96, 43, 47, 21, 72, 93, 96, 84, 76, 99, 85,
#        34, 83, 79, 37, 49, 75, 76,  3, 55, 52, 89, 68,  8, 46,  7, 74, 49,
#        85, 10, 18, 28, 39, 17, 46, 67, 50, 34,  6, 30, 19, 76, 26, 89, 49,
#         3, 23, 56, 69, 82, 91, 93, 86, 41, 97, 33, 91, 55, 44, 75, 44,  7,
#        84, 34, 41, 75, 67, 52, 17, 39, 24, 35, 11, 92,  5, 27, 70, 93,  9,
#        64, 64, 39, 12, 87, 48, 44,  3, 37, 64, 57, 19, 34, 68, 71, 71, 17,
#        56, 84, 29, 73,  8, 17,  2, 67, 57, 35, 28, 77, 27,  6, 56,  3, 91,
#        18, 70, 62, 61, 51, 23, 16, 42, 48, 73,  5, 26, 40])

# %%
x=np.arange(len(data))

# %%
y =data

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 200 artists>

# %%
plt.hist(data, bins=10, color='skyblue', edgecolor='black')
plt.show()

# %%
len(data[(data>=20) & (data<40)])
# Out:
# 206
