# %% [raw]
# STEP 0: IMPORTS AND READIND DATA

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
plt.style.use('ggplot')
# pd.set_option('max_columns', 200)
pd.set_option('display.max_columns', 200)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[23], line 6
#       4 import seaborn as sns
#       5 plt.style.use('ggplot')
# ----> 6 pd.set_option('max_columns', 200)
#       7 # pd.set_option('display.max_columns', 200)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:261, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     260 def __call__(self, *args, **kwds) -> T:
# --> 261     return self.__func__(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:156, in _set_option(*args, **kwargs)
#     153     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     155 for k, v in zip(args[::2], args[1::2]):
# --> 156     key = _get_single_key(k, silent)
#     158     o = _get_registered_option(key)
#     159     if o and o.validator:
#
# ...

# %%
df = pd.read_csv('archive/coaster_db.csv')
df
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head(10)
# Out:
#                              coaster_name            Length             Speed  \
# 0                      Switchback Railway    600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway               NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)               NaN               NaN
# 3            Loop the Loop (Coney Island)               NaN               NaN
# 4            Loop the Loop (Young's Pier)               NaN               NaN
# 5                          Cannon Coaster               NaN               NaN
# 6                           Leap-The-Dips  1,452 ft (443 m)  10 mph (16 km/h)
# 7        Figure Eight (Euclid Beach Park)               NaN               NaN
# 8                            Drop the Dip               NaN               NaN
# 9      Scenic Railway (Euclid Beach Park)               NaN               NaN
#
#                          Location     Status   Opening date  \
# ...

# %%
df.columns           #to seeall the columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [raw]
# SUBSETTING THE COLUMNS

# %%
df[['coaster_name', 
    # 'Length', 'Speed', 
    'Location', 'Status', 'Opening date',
       # 'Type',
    # 'Manufacturer', 'Height restriction', 'Model', 'Height',
       # 'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       # 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       # 'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       # 'Track layout', 'Fastrack available', 'Soft opening date.1',
       # 'Closing date', 'Opened', 'Replaced by', 'Website',
       # 'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       # 'Single rider line available', 'Restraint Style',
       # 'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    # 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    # 'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean']]
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
# EXAMPLE OF DROPPING COLUMN
# df.drop(['Status'] , axis = 1 )

# %% [raw]
# Selecting or making a copy of what seleted

# %%
df = df[['coaster_name', 
    # 'Length', 'Speed', 
    'Location', 'Status', 'Opening date',
       # 'Type',
    # 'Manufacturer', 'Height restriction', 'Model', 'Height',
       # 'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       # 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       # 'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       # 'Track layout', 'Fastrack available', 'Soft opening date.1',
       # 'Closing date', 'Opened', 'Replaced by', 'Website',
       # 'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       # 'Single rider line available', 'Restraint Style',
       # 'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    # 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    # 'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.shape
# Out:
# (1087, 13)

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Opening date           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
pd.to_datetime(df['opening_date_clean'])
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1082          NaT
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: datetime64[ns]

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
pd.to_numeric(df['year_introduced'])
# Out:
# 0       1884
# 1       1895
# 2       1896
# 3       1901
# 4       1901
#         ...
# 1082    2022
# 1083    2022
# 1084    2022
# 1085    2022
# 1086    2022
# Name: year_introduced, Length: 1087, dtype: int64

# %%
#rename our columns BY using DICTIONARY
df.rename(columns = {'coaster_name':'Coaster_Name',
                    'year_introduced':'Year_Introduced'})
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
#rename our columns BY using DICTIONARY

df = df.rename(columns = {'coaster_name':'Coaster_Name',
                    'year_introduced':'Year_Introduced'})

# %%
df
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status   Opening date  Year_Introduced  latitude  longitude Type_Main  \
# 0  Removed  June 16, 1884             1884   40.5740   -73.9780      Wood
# 1  Removed           1895             1895   40.5780   -73.9790      Wood
# 2   Closed            NaN             1896   41.5800   -81.5700     Other
# 3  Removed           1901             1901   40.5745   -73.9780     Steel
# 4  Removed           1901             1901   39.3538   -74.4342     Steel
#
#   opening_date_clean  speed_mph  height_ft  Inversions_clean  Gforce_clean
# ...

# %%
#for knoing is there any mssing values

# %%
df.isna().sum()
# Out:
# Coaster_Name            0
# Location                0
# Status                213
# Opening date          250
# Year_Introduced         0
# latitude              275
# longitude             275
# Type_Main               0
# opening_date_clean    250
# speed_mph             150
# height_ft             916
# Inversions_clean        0
# Gforce_clean          725
# dtype: int64

# %%
#check for dupplicates coaster name
df.duplicated(subset=['Coaster_Name'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082     True
# 1083    False
# 1084     True
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
#check for dupplicates coaster name
df.loc[df.duplicated(subset=['Coaster_Name'])].head(10)
# Out:
#                              Coaster_Name             Location     Status  \
# 43                  Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                            Derby Racer         Revere Beach    Removed
# 61            Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167         Big Thunder Mountain Railroad                Other        NaN
# 237     Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
# 239                             La Vibora                Other        NaN
# 241         Big Thunder Mountain Railroad                Other        NaN
# 252                             La Vibora                Other        NaN
# 262  Flashback (Six Flags Magic Mountain)                Other        NaN
# 270                        Alpine Bobsled                Other        NaN
#
#                                           Opening date  Year_Introduced  \
# 43                                                1926             1927
# ...

# %%
#checking an example duplicate
df.query('Coaster_Name =="Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status Opening date  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed         1926
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed         1926
#
#     Year_Introduced  latitude  longitude Type_Main opening_date_clean  \
# 39             1926   42.8617   -79.0598      Wood         1926-01-01
# 43             1927   42.8617   -79.0598      Wood         1926-01-01
#
#     speed_mph  height_ft  Inversions_clean  Gforce_clean
# 39       60.0        NaN                 0           4.0
# 43       60.0        NaN                 0           4.0

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Opening date', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
#checking the duplicates sum
df.duplicated(subset=['Coaster_Name', 'Location','opening_date_clean'])
df.duplicated(subset=['Coaster_Name', 'Location','opening_date_clean']).sum()
~df.duplicated(subset=['Coaster_Name', 'Location','opening_date_clean'])
df.loc[~df.duplicated(subset=['Coaster_Name', 'Location','opening_date_clean'])]
df.loc[~df.duplicated(subset=['Coaster_Name', 'Location','opening_date_clean'])]

# %%
df.loc[~df.duplicated(subset=['Coaster_Name', 'Location','opening_date_clean'])] \
.reset_index(drop = True)
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df = df.loc[~df.duplicated(subset=['Coaster_Name', 'Location','opening_date_clean'])] \
.reset_index(drop = True).copy()
#so we have done cleaning up our dataset

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
df['Year_Introduced'].value_counts() \
.head(10) \
.plot(kind = 'bar')                       
#horizontal bar='barh'
# Out:
# <Axes: xlabel='Year_Introduced'>

# %%
 graph = df['Year_Introduced'].value_counts() \
        .head(10) \
        .plot(kind = 'bar',title='Top 10 years coasters Introduced')
graph.set_xlabel('Year_Introduced')
graph.set_ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Opening date', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
ax= df['speed_mph'].plot(kind = 'hist' ,bins=20,title='coaster speed(mph)')
ax.set_xlabel('speed (mph)')
# Out:
# Text(0.5, 0, 'speed (mph)')

# %%
ax= df['speed_mph'].plot(kind = 'kde' ,
                         title='coaster speed(mph)')
ax.set_xlabel('speed (mph)')
# Out:
# Text(0.5, 0, 'speed (mph)')

# %%
df.plot(kind = 'scatter',
       x='speed_mph',
       y='height_ft',
       title='coaster speed vs. height')
# Out:
# <Axes: title={'center': 'coaster speed vs. height'}, xlabel='speed_mph', ylabel='height_ft'>

# %%
df.plot(kind = 'scatter',
       x='speed_mph',
       y='height_ft',
       title='coaster speed vs. height')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 5
#       1 df.plot(kind = 'scatter',
#       2        x='speed_mph',
#       3        y='height_ft',
#       4        title='coaster speed vs. height')
# ----> 5 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
sns.scatterplot(x='speed_mph',
               y='height_ft',
               hue = 'Year_Introduced',
               data = df)
# Out:
# <Axes: xlabel='speed_mph', ylabel='height_ft'>

# %%
ax=sns.scatterplot(x='speed_mph',
               y='height_ft',
               hue = 'Year_Introduced',
               data = df)
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[116], line 5
#       1 ax=sns.scatterplot(x='speed_mph',
#       2                y='height_ft',
#       3                hue = 'Year_Introduced',
#       4                data = df)
# ----> 5 ax.show()
#
# AttributeError: 'Axes' object has no attribute 'show'

# %%
#if i wnat to compare more features

# %%
 df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Opening date', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
sns.pairplot(df , vars=['Year_Introduced','speed_mph',
                           'height_ft', 'Inversions_clean', 'Gforce_clean'],
                  hue='Type_Main')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[127], line 4
#       1 sns.pairplot(df , vars=['Year_Introduced','speed_mph',
#       2                            'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       3             hue='Type_Main')
# ----> 4 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
#remove na
df_corr = df[['Year_Introduced','speed_mph',
                           'height_ft', 'Inversions_clean', 'Gforce_clean']].dropna().corr()

# %%
sns.heatmap(df_corr ,annot=True)
# Out:
# <Axes: >

# %% [raw]
# STEP 5 :ASK A QUESTION

# %%
# what are the locations with fastest roller coaster(min of 10)?

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Opening date', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df['Location'].value_counts()
# Out:
# Location
# Other                            181
# Kings Island                      19
# Cedar Point                       18
# Six Flags Magic Mountain          17
# Hersheypark                       16
#                                 ...
# Granada Studios Tour               1
# Funtown Splashtown USA             1
# Tolchester Beach Park              1
# Suzuka, Mie Prefecture, Japan      1
# Epcot                              1
# Name: count, Length: 280, dtype: int64

# %%
df.query('Location != "Other" ')  \
    .groupby('Location')['speed_mph'] \
    .agg(['mean','count']) \
    .query('count >=10' ) \
    .sort_values('mean')
# Out:
#                                  mean  count
# Location
# Alton Towers                42.791667     12
# Carowinds                   43.571429     14
# Kings Island                49.273684     19
# Hersheypark                 50.576923     13
# Kings Dominion              52.083333     12
# Six Flags Great Adventure   53.036364     11
# Canada's Wonderland         53.533333     12
# Six Flags Magic Mountain    57.241176     17
# Cedar Point                 57.833333     18
# Busch Gardens Williamsburg  58.318182     11

# %%
ax=df.query('Location != "Other" ')  \
    .groupby('Location')['speed_mph'] \
    .agg(['mean','count']) \
    .query('count >=10' ) \
    .sort_values('mean')['mean'] \
    .plot(kind='barh' ,figsize=(12,5) , title='Average coaster speed by Location')
ax.set_xlabel('Average coaster speed')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[143], line 8
#       1 ax=df.query('Location != "Other" ')  \
#       2     .groupby('Location')['speed_mph'] \
#       3     .agg(['mean','count']) \
#       4     .query('count >=10' ) \
#       5     .sort_values('mean')['mean'] \
#       6     .plot(kind='barh' ,figsize=(12,5) , title='Average coaster speed by Location')
#       7 ax.set_xlabel('Average coaster speed')
# ----> 8 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'
